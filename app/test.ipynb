# %%
import cohere
co = cohere.ClientV2('5ntGNZpen7VD9dsQEAIsT6ccmp9CO6sQaqMNdsVo')

# %%
response = co.embed(texts=['hello', 'goodby'], model="embed-english-v3.0", input_type='search_document', embedding_types= ['float'])

# %%
response.embeddings.float_[0]
# Out:
# [-0.0027694702,
#  0.017807007,
#  -0.04046631,
#  -0.06402588,
#  0.011924744,
#  -0.016296387,
#  -0.027801514,
#  0.002357483,
#  0.0009570122,
#  0.051818848,
#  -0.024734497,
#  -0.02708435,
#  0.030334473,
#  -0.032440186,
#  0.018112183,
#  -7.4505806e-05,
#  0.036315918,
#  0.034423828,
#  0.005115509,
#  -0.012664795,
#  -0.049102783,
#  0.023101807,
#  -0.02078247,
#  0.021194458,
#  0.036315918,
#  0.026977539,
#  -0.0039863586,
#  -0.0019874573,
#  -0.025634766,
#  -0.035614014,
#  0.008979797,
#  0.007663727,
#  0.028778076,
#  0.02482605,
#  -0.0016870499,
#  0.06726074,
#  -0.019515991,
#  -0.0048294067,
#  0.007896423,
#  0.0017938614,
#  0.026550293,
#  -0.025939941,
#  -0.07409668,
#  -0.028656006,
#  -0.07525635,
#  -0.025512695,
#  -0.0037765503,
#  0.0031414032,
#  0.029586792,
#  -0.030029297,
#  0.00084114075,
#  0.0037002563,
#  -0.0077705383,
#  0.059692383,
#  -0.016540527,
#  0.0088272095,
#  -0.060821533,
#  -0.018218994,
#  -0.0014333725,
#  0.035125732,
# ...
